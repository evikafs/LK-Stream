# %% [markdown]
# # Studi Kasus: Kafka Stream dari Sensor
#
# ## Overview
# Notebook ini mendemonstrasikan implementasi streaming data dari sensor menggunakan Apache Kafka. Kita akan membuat:
# 1. **Producer**: Mensimulasikan data sensor (suhu, kelembaban, tekanan)
# 2. **Consumer**: Membaca dan memproses data sensor
# 3. **Stream Processing**: Analisis real-time data sensor
#
# ## Prerequisites
# - Apache Kafka terinstall dan berjalan
# - Python 3.7+
# - Library: kafka-python, pandas, matplotlib

# %% [markdown]
# ## 1. Setup dan Import Library

# %%
# Install required packages
# !pip install kafka-python-ng pandas matplotlib numpy
# Out:
# Requirement already satisfied: kafka-python-ng in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (2.2.3)
# Requirement already satisfied: pandas in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (3.10.7)
# Requirement already satisfied: numpy in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\su'eb rizal\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\su'eb rizal\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\su'eb rizal\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\su'eb rizal\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import time
import random
from datetime import datetime
from kafka import KafkaProducer, KafkaConsumer
from kafka.errors import KafkaError
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import deque
import threading

print("✓ All libraries imported successfully")
# Out:
# ✓ All libraries imported successfully

# %% [markdown]
# ## 2. Konfigurasi Kafka

# %%
# Kafka Configuration
KAFKA_BOOTSTRAP_SERVERS = ['localhost:9092']
TOPIC_NAME = 'Suhu-Ruangan-Filkom'

# Sensor Configuration
SENSOR_IDS = ['TEMP_A01', 'TEMP_A02', 'TEMP_B01']
SENSOR_LOCATIONS = ['Gedung F', 'Gedung G', 'Gedung Kreativitas Mahasiswa']

print(f"Kafka Bootstrap Servers: {KAFKA_BOOTSTRAP_SERVERS}")
print(f"Topic: {TOPIC_NAME}")
print(f"Sensors: {SENSOR_IDS}")
# Out:
# Kafka Bootstrap Servers: ['localhost:9092']
# Topic: Suhu-Ruangan-Filkom
# Sensors: ['TEMP_A01', 'TEMP_A02', 'TEMP_B01']

# %% [markdown]
# ## 3. Fungsi Helper untuk Generate Data Sensor

# %%
def generate_sensor_data(sensor_id, location):
    """
    Generate data sensor yang realistis dan sesuai threshold.
    - Suhu: 20-35°C
    - Kelembaban: 40-80%
    - Tekanan: 1000-1020 hPa
    - Status: normal / warning berdasarkan threshold
    """
    # Base values per lokasi
    base_temps = {
        'Gedung F': 22.0,
        'Gedung G': 20.0,
        'Gedung Kreativitas Mahsiswa': 25.0
    }
    base_temp = base_temps.get(location, 25.0)
    
    temperature = round(base_temp + random.uniform(-3, 3), 2)
    humidity = round(random.uniform(40, 80), 2)
    pressure = round(random.uniform(1000, 1020), 2)
    
    # Tentukan status berdasarkan threshold
    status = 'normal'
    if temperature > 30 or humidity > 75:
        status = 'warning'
    
    sensor_reading = {
        'sensor_id': sensor_id,
        'location': location,
        'timestamp': datetime.now().isoformat(),
        'temperature': temperature,
        'humidity': humidity,
        'pressure': pressure,
        'status': status
    }
    
    return sensor_reading

# Test function
sample_data = generate_sensor_data('TEMP_A01', 'Gedung F')
print("Sample sensor data:")
print(json.dumps(sample_data, indent=2))
# Out:
# Sample sensor data:
# {
#   "sensor_id": "TEMP_A01",
#   "location": "Gedung F",
#   "timestamp": "2025-10-30T18:02:11.495239",
#   "temperature": 21.19,
#   "humidity": 63.02,
#   "pressure": 1013.26,
#   "status": "normal"
# }

# %% [markdown]
# ## 4. Kafka Producer - Mensimulasikan Data Sensor

# %%
class SensorProducer:
    def __init__(self, bootstrap_servers, topic_name):
        self.producer = KafkaProducer(
            bootstrap_servers=bootstrap_servers,
            value_serializer=lambda v: json.dumps(v).encode('utf-8'),
            key_serializer=lambda k: k.encode('utf-8') if k else None
        )
        self.topic_name = topic_name
        self.running = False
        
    def send_sensor_data(self, sensor_id, location):
        """Send single sensor reading to Kafka"""
        data = generate_sensor_data(sensor_id, location)
        
        try:
            future = self.producer.send(
                self.topic_name,
                key=sensor_id,
                value=data
            )
            # Wait for send to complete
            record_metadata = future.get(timeout=10)
            return True, data
        except KafkaError as e:
            print(f"Error sending data: {e}")
            return False, None
    
    def start_streaming(self, duration_seconds=30, interval=2):
        """Stream sensor data for specified duration"""
        self.running = True
        start_time = time.time()
        messages_sent = 0
        
        print(f"🚀 Starting sensor data streaming for {duration_seconds} seconds...")
        print(f"Sending data every {interval} seconds\n")
        
        try:
            while self.running and (time.time() - start_time) < duration_seconds:
                # Send data from all sensors
                for sensor_id, location in zip(SENSOR_IDS, SENSOR_LOCATIONS):
                    success, data = self.send_sensor_data(sensor_id, location)
                    if success:
                        messages_sent += 1
                        print(f"✓ [{data['timestamp']}] {sensor_id} ({location}): "
                              f"Temp={data['temperature']}°C, "
                              f"Humidity={data['humidity']}%, "
                              f"Status={data['status']}")
                
                time.sleep(interval)
                
        except KeyboardInterrupt:
            print("\n⚠️ Streaming interrupted by user")
        finally:
            self.producer.flush()
            print(f"\n✅ Streaming completed. Total messages sent: {messages_sent}")
    
    def stop(self):
        """Stop streaming"""
        self.running = False
        self.producer.close()

print("✓ SensorProducer class defined")
# Out:
# ✓ SensorProducer class defined

# %% [markdown]
# ## 5. Test Producer - Kirim Data Sensor

# %%
# Initialize producer
producer = SensorProducer(KAFKA_BOOTSTRAP_SERVERS, TOPIC_NAME)

# Stream data for 30 seconds (interval 2 seconds)
producer.start_streaming(duration_seconds=30, interval=2)

# Clean up
producer.stop()
# Out:
# 🚀 Starting sensor data streaming for 30 seconds...
# Sending data every 2 seconds
#
# ✓ [2025-10-30T18:02:11.619842] TEMP_A01 (Gedung F): Temp=24.14°C, Humidity=64.03%, Status=normal
# ✓ [2025-10-30T18:02:11.626463] TEMP_A02 (Gedung G): Temp=17.56°C, Humidity=75.08%, Status=warning
# ✓ [2025-10-30T18:02:11.627620] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=25.2°C, Humidity=52.02%, Status=normal
# ✓ [2025-10-30T18:02:13.629133] TEMP_A01 (Gedung F): Temp=23.36°C, Humidity=69.71%, Status=normal
# ✓ [2025-10-30T18:02:13.633613] TEMP_A02 (Gedung G): Temp=18.17°C, Humidity=78.4%, Status=warning
# ✓ [2025-10-30T18:02:13.636668] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=25.68°C, Humidity=61.45%, Status=normal
# ✓ [2025-10-30T18:02:15.640738] TEMP_A01 (Gedung F): Temp=20.56°C, Humidity=78.81%, Status=warning
# ✓ [2025-10-30T18:02:15.645714] TEMP_A02 (Gedung G): Temp=18.92°C, Humidity=42.93%, Status=normal
# ✓ [2025-10-30T18:02:15.649616] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=24.65°C, Humidity=51.55%, Status=normal
# ✓ [2025-10-30T18:02:17.653815] TEMP_A01 (Gedung F): Temp=20.76°C, Humidity=63.94%, Status=normal
# ✓ [2025-10-30T18:02:17.655841] TEMP_A02 (Gedung G): Temp=18.46°C, Humidity=66.49%, Status=normal
# ✓ [2025-10-30T18:02:17.657781] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=22.46°C, Humidity=48.43%, Status=normal
# ✓ [2025-10-30T18:02:19.659358] TEMP_A01 (Gedung F): Temp=20.72°C, Humidity=62.61%, Status=normal
# ✓ [2025-10-30T18:02:19.662486] TEMP_A02 (Gedung G): Temp=19.96°C, Humidity=52.92%, Status=normal
# ✓ [2025-10-30T18:02:19.665061] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=27.57°C, Humidity=69.05%, Status=normal
# ✓ [2025-10-30T18:02:21.667644] TEMP_A01 (Gedung F): Temp=22.4°C, Humidity=40.39%, Status=normal
# ✓ [2025-10-30T18:02:21.675135] TEMP_A02 (Gedung G): Temp=18.04°C, Humidity=50.57%, Status=normal
# ✓ [2025-10-30T18:02:21.681383] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=25.92°C, Humidity=68.82%, Status=normal
# ✓ [2025-10-30T18:02:23.685450] TEMP_A01 (Gedung F): Temp=23.77°C, Humidity=63.53%, Status=normal
# ✓ [2025-10-30T18:02:23.692040] TEMP_A02 (Gedung G): Temp=22.03°C, Humidity=68.65%, Status=normal
# ✓ [2025-10-30T18:02:23.695596] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=26.19°C, Humidity=73.9%, Status=normal
# ✓ [2025-10-30T18:02:25.698948] TEMP_A01 (Gedung F): Temp=24.46°C, Humidity=62.35%, Status=normal
# ✓ [2025-10-30T18:02:25.701893] TEMP_A02 (Gedung G): Temp=22.69°C, Humidity=48.43%, Status=normal
# ✓ [2025-10-30T18:02:25.703647] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=27.19°C, Humidity=54.25%, Status=normal
# ✓ [2025-10-30T18:02:27.706178] TEMP_A01 (Gedung F): Temp=22.51°C, Humidity=55.0%, Status=normal
# ✓ [2025-10-30T18:02:27.711945] TEMP_A02 (Gedung G): Temp=18.85°C, Humidity=50.72%, Status=normal
# ✓ [2025-10-30T18:02:27.717076] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=27.11°C, Humidity=54.79%, Status=normal
# ✓ [2025-10-30T18:02:29.721104] TEMP_A01 (Gedung F): Temp=22.06°C, Humidity=58.86%, Status=normal
# ✓ [2025-10-30T18:02:29.728937] TEMP_A02 (Gedung G): Temp=22.49°C, Humidity=75.61%, Status=warning
# ✓ [2025-10-30T18:02:29.731998] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=25.71°C, Humidity=53.51%, Status=normal
# ✓ [2025-10-30T18:02:31.735666] TEMP_A01 (Gedung F): Temp=24.46°C, Humidity=68.96%, Status=normal
# ✓ [2025-10-30T18:02:31.742686] TEMP_A02 (Gedung G): Temp=22.92°C, Humidity=40.54%, Status=normal
# ✓ [2025-10-30T18:02:31.747118] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=22.37°C, Humidity=75.52%, Status=warning
# ✓ [2025-10-30T18:02:33.750807] TEMP_A01 (Gedung F): Temp=24.96°C, Humidity=61.71%, Status=normal
# ✓ [2025-10-30T18:02:33.755592] TEMP_A02 (Gedung G): Temp=18.2°C, Humidity=76.75%, Status=warning
# ✓ [2025-10-30T18:02:33.760187] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=24.31°C, Humidity=62.33%, Status=normal
# ✓ [2025-10-30T18:02:35.763158] TEMP_A01 (Gedung F): Temp=22.28°C, Humidity=41.69%, Status=normal
# ✓ [2025-10-30T18:02:35.769440] TEMP_A02 (Gedung G): Temp=22.87°C, Humidity=52.43%, Status=normal
# ✓ [2025-10-30T18:02:35.776168] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=27.63°C, Humidity=40.76%, Status=normal
# ✓ [2025-10-30T18:02:37.781788] TEMP_A01 (Gedung F): Temp=23.2°C, Humidity=70.61%, Status=normal
# ✓ [2025-10-30T18:02:37.788084] TEMP_A02 (Gedung G): Temp=19.77°C, Humidity=79.01%, Status=warning
# ✓ [2025-10-30T18:02:37.793330] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=24.19°C, Humidity=51.09%, Status=normal
# ✓ [2025-10-30T18:02:39.797273] TEMP_A01 (Gedung F): Temp=19.56°C, Humidity=67.95%, Status=normal
# ✓ [2025-10-30T18:02:39.802530] TEMP_A02 (Gedung G): Temp=22.98°C, Humidity=42.8%, Status=normal
# ✓ [2025-10-30T18:02:39.805780] TEMP_B01 (Gedung Kreativitas Mahasiswa): Temp=26.77°C, Humidity=52.22%, Status=normal
#
# ✅ Streaming completed. Total messages sent: 45

# %% [markdown]
# ## 6. Kafka Consumer - Membaca Data Sensor

# %%
class SensorConsumer:
    def __init__(self, bootstrap_servers, topic_name, group_id='sensor-consumer-group'):
        self.consumer = KafkaConsumer(
            topic_name,
            bootstrap_servers=bootstrap_servers,
            group_id=group_id,
            auto_offset_reset='earliest',  # Start from beginning
            enable_auto_commit=True,
            value_deserializer=lambda m: json.loads(m.decode('utf-8'))
        )
        self.data_buffer = []
        self.running = False
        
    def consume_messages(self, max_messages=50, timeout_ms=10000):
        """Consume messages from Kafka"""
        self.running = True
        messages_consumed = 0
        
        print(f"📥 Starting to consume messages (max: {max_messages})...\n")
        
        try:
            for message in self.consumer:
                if not self.running or messages_consumed >= max_messages:
                    break
                    
                data = message.value
                self.data_buffer.append(data)
                messages_consumed += 1
                
                # Display message
                status_icon = "⚠️" if data['status'] == 'warning' else "✓"
                print(f"{status_icon} Message {messages_consumed}: "
                      f"{data['sensor_id']} - Temp: {data['temperature']}°C, "
                      f"Humidity: {data['humidity']}%, "
                      f"Status: {data['status']}")
                
        except KeyboardInterrupt:
            print("\n⚠️ Consumption interrupted by user")
        finally:
            print(f"\n✅ Consumed {messages_consumed} messages")
            return self.data_buffer
    
    def get_dataframe(self):
        """Convert buffer to pandas DataFrame"""
        if not self.data_buffer:
            return pd.DataFrame()
        return pd.DataFrame(self.data_buffer)
    
    def stop(self):
        """Stop consumer"""
        self.running = False
        self.consumer.close()

print("✓ SensorConsumer class defined")
# Out:
# ✓ SensorConsumer class defined
# <>:41: SyntaxWarning: 'return' in a 'finally' block
# C:\Users\su'eb rizal\AppData\Local\Temp\ipykernel_21696\1092943057.py:41: SyntaxWarning: 'return' in a 'finally' block
#   return self.data_buffer
# C:\Users\su'eb rizal\AppData\Local\Temp\ipykernel_21696\1092943057.py:41: SyntaxWarning: 'return' in a 'finally' block
#   return self.data_buffer

# %% [markdown]
# ## 7. Test Consumer - Baca Data Sensor

# %%
# Initialize consumer
consumer = SensorConsumer(KAFKA_BOOTSTRAP_SERVERS, TOPIC_NAME)

# Consume messages
messages = consumer.consume_messages(max_messages=50)

# Convert to DataFrame
df = consumer.get_dataframe()

# Display summary
print("\n" + "="*60)
print("DATA SUMMARY")
print("="*60)
print(f"Total records: {len(df)}")
print(f"\nFirst 5 records:")
print(df.head())

# Clean up
consumer.stop()
# Out:
# 📥 Starting to consume messages (max: 50)...
#
# ✓ Message 1: TEMP_A01 - Temp: 24.14°C, Humidity: 64.03%, Status: normal
# ⚠️ Message 2: TEMP_A02 - Temp: 17.56°C, Humidity: 75.08%, Status: warning
# ✓ Message 3: TEMP_B01 - Temp: 25.2°C, Humidity: 52.02%, Status: normal
# ✓ Message 4: TEMP_A01 - Temp: 23.36°C, Humidity: 69.71%, Status: normal
# ⚠️ Message 5: TEMP_A02 - Temp: 18.17°C, Humidity: 78.4%, Status: warning
# ✓ Message 6: TEMP_B01 - Temp: 25.68°C, Humidity: 61.45%, Status: normal
# ⚠️ Message 7: TEMP_A01 - Temp: 20.56°C, Humidity: 78.81%, Status: warning
# ✓ Message 8: TEMP_A02 - Temp: 18.92°C, Humidity: 42.93%, Status: normal
# ✓ Message 9: TEMP_B01 - Temp: 24.65°C, Humidity: 51.55%, Status: normal
# ✓ Message 10: TEMP_A01 - Temp: 20.76°C, Humidity: 63.94%, Status: normal
# ✓ Message 11: TEMP_A02 - Temp: 18.46°C, Humidity: 66.49%, Status: normal
# ✓ Message 12: TEMP_B01 - Temp: 22.46°C, Humidity: 48.43%, Status: normal
# ✓ Message 13: TEMP_A01 - Temp: 20.72°C, Humidity: 62.61%, Status: normal
# ✓ Message 14: TEMP_A02 - Temp: 19.96°C, Humidity: 52.92%, Status: normal
# ✓ Message 15: TEMP_B01 - Temp: 27.57°C, Humidity: 69.05%, Status: normal
# ✓ Message 16: TEMP_A01 - Temp: 22.4°C, Humidity: 40.39%, Status: normal
# ✓ Message 17: TEMP_A02 - Temp: 18.04°C, Humidity: 50.57%, Status: normal
# ✓ Message 18: TEMP_B01 - Temp: 25.92°C, Humidity: 68.82%, Status: normal
# ✓ Message 19: TEMP_A01 - Temp: 23.77°C, Humidity: 63.53%, Status: normal
# ✓ Message 20: TEMP_A02 - Temp: 22.03°C, Humidity: 68.65%, Status: normal
# ✓ Message 21: TEMP_B01 - Temp: 26.19°C, Humidity: 73.9%, Status: normal
# ✓ Message 22: TEMP_A01 - Temp: 24.46°C, Humidity: 62.35%, Status: normal
# ✓ Message 23: TEMP_A02 - Temp: 22.69°C, Humidity: 48.43%, Status: normal
# ✓ Message 24: TEMP_B01 - Temp: 27.19°C, Humidity: 54.25%, Status: normal
# ✓ Message 25: TEMP_A01 - Temp: 22.51°C, Humidity: 55.0%, Status: normal
# ✓ Message 26: TEMP_A02 - Temp: 18.85°C, Humidity: 50.72%, Status: normal
# ✓ Message 27: TEMP_B01 - Temp: 27.11°C, Humidity: 54.79%, Status: normal
# ✓ Message 28: TEMP_A01 - Temp: 22.06°C, Humidity: 58.86%, Status: normal
# ⚠️ Message 29: TEMP_A02 - Temp: 22.49°C, Humidity: 75.61%, Status: warning
# ✓ Message 30: TEMP_B01 - Temp: 25.71°C, Humidity: 53.51%, Status: normal
# ✓ Message 31: TEMP_A01 - Temp: 24.46°C, Humidity: 68.96%, Status: normal
# ✓ Message 32: TEMP_A02 - Temp: 22.92°C, Humidity: 40.54%, Status: normal
# ⚠️ Message 33: TEMP_B01 - Temp: 22.37°C, Humidity: 75.52%, Status: warning
# ✓ Message 34: TEMP_A01 - Temp: 24.96°C, Humidity: 61.71%, Status: normal
# ⚠️ Message 35: TEMP_A02 - Temp: 18.2°C, Humidity: 76.75%, Status: warning
# ✓ Message 36: TEMP_B01 - Temp: 24.31°C, Humidity: 62.33%, Status: normal
# ✓ Message 37: TEMP_A01 - Temp: 22.28°C, Humidity: 41.69%, Status: normal
# ✓ Message 38: TEMP_A02 - Temp: 22.87°C, Humidity: 52.43%, Status: normal
# ✓ Message 39: TEMP_B01 - Temp: 27.63°C, Humidity: 40.76%, Status: normal
# ✓ Message 40: TEMP_A01 - Temp: 23.2°C, Humidity: 70.61%, Status: normal
# ⚠️ Message 41: TEMP_A02 - Temp: 19.77°C, Humidity: 79.01%, Status: warning
# ✓ Message 42: TEMP_B01 - Temp: 24.19°C, Humidity: 51.09%, Status: normal
# ✓ Message 43: TEMP_A01 - Temp: 19.56°C, Humidity: 67.95%, Status: normal
# ✓ Message 44: TEMP_A02 - Temp: 22.98°C, Humidity: 42.8%, Status: normal
# ✓ Message 45: TEMP_B01 - Temp: 26.77°C, Humidity: 52.22%, Status: normal

# %% [markdown]
# ## 8. Analisis Data Sensor

# %%
# Basic statistics
if not df.empty:
    print("📊 STATISTIK DATA SENSOR")
    print("="*60)
    
    # Group by sensor
    sensor_stats = df.groupby('sensor_id').agg({
        'temperature': ['mean', 'min', 'max', 'std'],
    }).round(2)
    
    print(sensor_stats)
    
    # Status distribution
    print("\n📈 DISTRIBUSI STATUS")
    print("="*60)
    status_counts = df['status'].value_counts()
    print(status_counts)
    
    # Warnings by sensor
    print("\n⚠️ WARNING COUNT PER SENSOR")
    print("="*60)
    warnings = df[df['status'] == 'warning'].groupby('sensor_id').size()
    print(warnings)
else:
    print("⚠️ No data available for analysis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Basic statistics
# ----> 2 if not df.empty:
#       3     print("📊 STATISTIK DATA SENSOR")
#       4     print("="*60)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 9. Visualisasi Data Sensor

# %%
if not df.empty:
    # Convert timestamp to datetime
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df = df.sort_values('timestamp')
    
    # Hanya satu parameter: suhu
    fig, ax = plt.subplots(1, 1, figsize=(14, 6))
    fig.suptitle('🌡️ Monitoring Suhu di FILKOM', fontsize=16, fontweight='bold')
    
    for sensor_id in SENSOR_IDS:
        sensor_data = df[df['sensor_id'] == sensor_id]
        ax.plot(sensor_data['timestamp'], sensor_data['temperature'], 
                marker='o', label=sensor_id, linewidth=2, markersize=4)
    
    ax.set_title('Suhu Ruangan Over Time', fontsize=12, fontweight='bold')
    ax.set_ylabel('Temperature (°C)')
    ax.set_xlabel('Timestamp')
    ax.axhline(y=30, color='r', linestyle='--', alpha=0.5, label='Threshold Suhu Maksimal')
    ax.legend()
    ax.grid(True, alpha=0.3)
    ax.tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 10. Stream Processing dengan Windowing

# %%
class StreamProcessor:
    def __init__(self, window_size=10):
        self.window_size = window_size
        self.windows = {
            sensor_id: {
                'temperature': deque(maxlen=window_size),
                'humidity': deque(maxlen=window_size),
                'pressure': deque(maxlen=window_size)
            }
            for sensor_id in SENSOR_IDS
        }
        self.alerts = []
    
    def process_message(self, data):
        """Process incoming sensor message"""
        sensor_id = data['sensor_id']
        
        # Add to window
        self.windows[sensor_id]['temperature'].append(data['temperature'])
        self.windows[sensor_id]['humidity'].append(data['humidity'])
        self.windows[sensor_id]['pressure'].append(data['pressure'])
        
        # Calculate moving averages
        avg_temp = np.mean(self.windows[sensor_id]['temperature'])
        avg_humidity = np.mean(self.windows[sensor_id]['humidity'])
        avg_pressure = np.mean(self.windows[sensor_id]['pressure'])
        
        # Check for anomalies
        alerts = []
        if avg_temp < 20:
            alerts.append(f"🔥 High temperature alert: {avg_temp:.2f}°C")
        
        result = {
            'sensor_id': sensor_id,
            'location': data['location'],
            'timestamp': data['timestamp'],
            'current': {
                'temperature': data['temperature']
            },
            'moving_avg': {
                'temperature': round(avg_temp, 2),
            },
            'window_size': len(self.windows[sensor_id]['temperature']),
            'alerts': alerts
        }
        
        if alerts:
            self.alerts.append(result)
        
        return result
    
    def get_statistics(self, sensor_id):
        """Get statistics for a sensor"""
        if sensor_id not in self.windows:
            return None
        
        window = self.windows[sensor_id]
        return {
            'sensor_id': sensor_id,
            'temperature': {
                'mean': np.mean(window['temperature']),
                'std': np.std(window['temperature']),
                'min': np.min(window['temperature']),
                'max': np.max(window['temperature'])
        }
        
print("✓ StreamProcessor class defined")

# %% [markdown]
# ## 11. Test Stream Processing

# %%
# Initialize stream processor
processor = StreamProcessor(window_size=5)

print("🔄 Processing sensor data with windowing...\n")

# Process existing data
if not df.empty:
    for idx, row in df.iterrows():
        data = row.to_dict()
        result = processor.process_message(data)
        
        # Print results for every 5th message
        if (idx + 1) % 5 == 0:
            print(f"\n{'='*70}")
            print(f"Message {idx + 1}: {result['sensor_id']} - {result['location']}")
            print(f"{'='*70}")
            print(f"Current:     Temp={result['current']['temperature']}°C, "
                  f"Humidity={result['current']['humidity']}%, "
                  f"Pressure={result['current']['pressure']} hPa")
            print(f"Moving Avg:  Temp={result['moving_avg']['temperature']}°C, "
                  f"Humidity={result['moving_avg']['humidity']}%, "
                  f"Pressure={result['moving_avg']['pressure']} hPa")
            print(f"Window Size: {result['window_size']}")
            
            if result['alerts']:
                print("\n⚠️ ALERTS:")
                for alert in result['alerts']:
                    print(f"  - {alert}")
    
    # Show all alerts
    if processor.alerts:
        print(f"\n\n{'='*70}")
        print(f"📋 TOTAL ALERTS: {len(processor.alerts)}")
        print(f"{'='*70}")
        for alert_data in processor.alerts[-5:]:  # Show last 5 alerts
            print(f"\n{alert_data['sensor_id']} - {alert_data['location']}:")
            for alert in alert_data['alerts']:
                print(f"  {alert}")
    
    # Show statistics for each sensor
    print(f"\n\n{'='*70}")
    print("📊 SENSOR STATISTICS (Window-based)")
    print(f"{'='*70}")
    for sensor_id in SENSOR_IDS:
        stats = processor.get_statistics(sensor_id)
        if stats:
            print(f"\n{sensor_id}:")
            print(f"  Temperature: {stats['temperature']['mean']:.2f}°C "
                  f"(±{stats['temperature']['std']:.2f}, "
                  f"range: {stats['temperature']['min']:.2f}-{stats['temperature']['max']:.2f})")
            print(f"  Humidity:    {stats['humidity']['mean']:.2f}% "
                  f"(±{stats['humidity']['std']:.2f})")
            print(f"  Pressure:    {stats['pressure']['mean']:.2f} hPa "
                  f"(±{stats['pressure']['std']:.2f})")
else:
    print("⚠️ No data available for processing")

# %% [markdown]
# ## 12. End-to-End Demo: Producer + Consumer + Processing

# %%
def run_full_demo(duration=20, interval=2):
    """
    Menjalankan demo lengkap:
    1. Producer mengirim data
    2. Consumer membaca data
    3. Stream processor menganalisis real-time
    """
    print("🚀 Starting Full Kafka Stream Demo...\n")
    print(f"Duration: {duration} seconds")
    print(f"Interval: {interval} seconds")
    print("="*70 + "\n")
    
    # Initialize components
    producer = SensorProducer(KAFKA_BOOTSTRAP_SERVERS, TOPIC_NAME)
    consumer = KafkaConsumer(
        TOPIC_NAME,
        bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
        auto_offset_reset='latest',
        enable_auto_commit=True,
        value_deserializer=lambda m: json.loads(m.decode('utf-8')),
        consumer_timeout_ms=1000
    )
    processor = StreamProcessor(window_size=3)
    
    results = []
    start_time = time.time()
    
    try:
        while (time.time() - start_time) < duration:
            # Produce data
            print(f"\n⏱️  Time: {int(time.time() - start_time)}s")
            print("-" * 70)
            
            for sensor_id, location in zip(SENSOR_IDS, SENSOR_LOCATIONS):
                success, data = producer.send_sensor_data(sensor_id, location)
                if success:
                    print(f"📤 Sent: {sensor_id} - Temp={data['temperature']}°C")
            
            # Small delay to allow message propagation
            time.sleep(0.5)
            
            # Consume and process
            for message in consumer:
                data = message.value
                result = processor.process_message(data)
                results.append(result)
                
                status = "⚠️" if result['alerts'] else "✓"
                print(f"{status} Processed: {result['sensor_id']} - "
                      f"MA Temp={result['moving_avg']['temperature']}°C")
                
                if result['alerts']:
                    for alert in result['alerts']:
                        print(f"  🚨 {alert}")
            
            time.sleep(interval - 0.5)
    
    except KeyboardInterrupt:
        print("\n⚠️ Demo interrupted by user")
    
    finally:
        producer.stop()
        consumer.close()
        
        print(f"\n\n{'='*70}")
        print("✅ DEMO COMPLETED")
        print(f"{'='*70}")
        print(f"Total messages processed: {len(results)}")
        print(f"Total alerts generated: {len(processor.alerts)}")
        
        return pd.DataFrame(results)

# Run the demo
# Uncomment to run:
# results_df = run_full_demo(duration=20, interval=2)
# print("\nResults DataFrame:")
# print(results_df.head(10))

print("✓ Demo function ready. Uncomment the last lines to run the full demo.")

# %% [markdown]
# Menambah Data Real dari Sensor

# %%
# TODO 7: Data real dari sensor
import Adafruit_DHT

def read_real_sensor_data(sensor_id, gpio_pin, location='Lab IoT'):
    """Baca data dari sensor DHT22"""
    sensor = Adafruit_DHT.DHT22
    humidity, temperature = Adafruit_DHT.read_retry(sensor, gpio_pin)
    
    if humidity is not None and temperature is not None:
        return {
            'sensor_id': sensor_id,
            'location': location,
            'timestamp': datetime.now().isoformat(),
            'temperature': round(temperature, 2),
            'humidity': round(humidity, 2),
            'pressure': None,  # Tidak tersedia dari DHT22
            'status': 'normal' if temperature < 30 else 'warning'
        }
    else:
        return None

# %% [markdown]
# Menyimpan data suhu

# %%
# TODO 8: Simpan data monitoring suhu Filkom ke Database
import psycopg2

def save_to_database(data):
    """Simpan data sensor suhu Filkom ke PostgreSQL"""
    try:
        conn = psycopg2.connect(
            host="localhost",
            database="filkom_suhu_db",  # ganti sesuai nama DB
            user="evikafs",
            password="1234"
        )
        cur = conn.cursor()
        
        # Masukkan data sesuai use case: suhu, kelembaban, status
        cur.execute("""
            INSERT INTO suhu_readings 
            (sensor_id, location, timestamp, temperature, humidity, status)
            VALUES (%s, %s, %s, %s, %s, %s)
        """, (
            data['sensor_id'],
            data['location'],
            data['timestamp'],
            data['temperature'],
            data['humidity'],
            data['status']
        ))
        
        conn.commit()
        cur.close()
        conn.close()
        print(f"💾 Data saved: {data['sensor_id']} at {data['timestamp']}")
    except Exception as e:
        print(f"❌ Failed to save data: {e}")

# %% [markdown]
# Membuat dashboard real time

# %%
# TODO 9: Dashboard Real-time 📊 untuk monitoring suhu di Filkom
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from IPython.display import clear_output
import pandas as pd
import time
import random
from datetime import datetime

# Data buffer untuk menampung data sensor (dummy)
data_buffer = []

# Fungsi generate data dummy sesuai To Do sebelumnya
def generate_sensor_data(sensor_id, location):
    base_temps = {
        'Gedung F': 22.0,
        'Gedung G': 20.0,
        'Gedung Kreativitas Mahasiswa': 25.0
    }
    base_temp = base_temps.get(location, 25.0)
    
    temperature = round(base_temp + random.uniform(-3, 3), 2)
    humidity = round(random.uniform(40, 80), 2)
    
    status = 'normal'
    if temperature > 30 or humidity > 75:
        status = 'warning'
    
    return {
        'sensor_id': sensor_id,
        'location': location,
        'timestamp': datetime.now().isoformat(),
        'temperature': temperature,
        'humidity': humidity,
        'status': status
    }

# List sensor dan lokasi
SENSOR_IDS = ['TEMP_A01', 'TEMP_B02', 'TEMP_C03']
SENSOR_LOCATIONS = ['Gedung F', 'Gedung G', 'Gedung Kreativitas Mahasiswa']

def create_live_dashboard(update_interval=2, max_points=50):
    """Dashboard live update suhu dan kelembaban"""
    
    fig = make_subplots(
        rows=2, cols=1,
        subplot_titles=('🌡️ Temperature (°C)', '💧 Humidity (%)')
    )
    
    # Simulasi data streaming
    while True:
        # Generate data dummy untuk semua sensor
        for sensor_id, location in zip(SENSOR_IDS, SENSOR_LOCATIONS):
            data = generate_sensor_data(sensor_id, location)
            data_buffer.append(data)
        
        # Batasi panjang buffer
        if len(data_buffer) > max_points * len(SENSOR_IDS):
            data_buffer[:] = data_buffer[-max_points * len(SENSOR_IDS):]
        
        # Convert ke DataFrame
        df = pd.DataFrame(data_buffer)
        df['timestamp'] = pd.to_datetime(df['timestamp'])
        
        # Clear figure untuk update
        fig.data = []
        
        # Plot suhu
        for sensor_id in SENSOR_IDS:
            sensor_df = df[df['sensor_id'] == sensor_id]
            fig.add_trace(
                go.Scatter(
                    x=sensor_df['timestamp'],
                    y=sensor_df['temperature'],
                    mode='lines+markers',
                    name=f"{sensor_id} ({sensor_df['location'].iloc[0]})"
                ),
                row=1, col=1
            )
        fig.update_yaxes(title_text="Temperature (°C)", row=1, col=1)
        fig.update_xaxes(title_text="Timestamp", row=1, col=1)
        fig.add_hline(y=30, line_dash="dash", line_color="red", row=1, col=1, annotation_text="Warning Temp")
        
        # Plot kelembaban
        for sensor_id in SENSOR_IDS:
            sensor_df = df[df['sensor_id'] == sensor_id]
            fig.add_trace(
                go.Scatter(
                    x=sensor_df['timestamp'],
                    y=sensor_df['humidity'],
                    mode='lines+markers',
                    name=f"{sensor_id} ({sensor_df['location'].iloc[0]})"
                ),
                row=2, col=1
            )
        fig.update_yaxes(title_text="Humidity (%)", row=2, col=1)
        fig.update_xaxes(title_text="Timestamp", row=2, col=1)
        fig.add_hline(y=75, line_dash="dash", line_color="red", row=2, col=1, annotation_text="Warning Humidity")
        
        # Tampilkan figure
        clear_output(wait=True)
        fig.show()
        
        time.sleep(update_interval)

# %% [markdown]
# Testing dan Validasi

# %%
# TODO 10: Testing dan Validasi ✅

from datetime import datetime

def validate_sensor_data(data):
    """
    Validasi data sensor suhu di Filkom sebelum dikirim/diolah
    """
    required_fields = ['sensor_id', 'location', 'timestamp', 'temperature', 'humidity', 'status']
    
    # Cek semua field wajib ada
    for field in required_fields:
        if field not in data:
            raise ValueError(f"Missing required field: {field}")
    
    # Validasi suhu
    if not 0 <= data['temperature'] <= 50:  # Sesuai range suhu gedung
        raise ValueError(f"Temperature out of range: {data['temperature']}°C")
    
    # Validasi kelembaban
    if not 0 <= data['humidity'] <= 100:
        raise ValueError(f"Humidity out of range: {data['humidity']}%")
    
    # Validasi status
    if data['status'] not in ['normal', 'warning']:
        raise ValueError(f"Invalid status: {data['status']}")
    
    # Validasi timestamp
    try:
        datetime.fromisoformat(data['timestamp'])
    except ValueError:
        raise ValueError("Invalid timestamp format")
    
    return True

# Contoh penggunaan sebelum mengirim data ke Kafka atau menyimpan ke DB
sample_data = generate_sensor_data('TEMP_A01', 'Gedung F')

try:
    if validate_sensor_data(sample_data):
        print("✅ Data valid, siap dikirim")
except ValueError as e:
    print(f"⚠️ Data invalid: {e}")

# Contoh unit test sederhana
def test_validate_sensor_data():
    valid_data = {
        'sensor_id': 'TEMP_A01',
        'location': 'Gedung F',
        'timestamp': datetime.now().isoformat(),
        'temperature': 25,
        'humidity': 50,
        'status': 'normal'
    }
    
    invalid_data_missing_field = valid_data.copy()
    del invalid_data_missing_field['temperature']
    
    invalid_data_temp = valid_data.copy()
    invalid_data_temp['temperature'] = 100  # Out of range
    
    assert validate_sensor_data(valid_data) == True
    try:
        validate_sensor_data(invalid_data_missing_field)
    except ValueError as e:
        print(f"Expected error: {e}")
    try:
        validate_sensor_data(invalid_data_temp)
    except ValueError as e:
        print(f"Expected error: {e}")

# Jalankan unit test
test_validate_sensor_data()

# %% [markdown]
# ## 14. 📝 TODO: Adaptasi untuk Data Sensor Anda Sendiri
#
# ### 🎯 **Tugas untuk Mahasiswa**
#
# Ikuti langkah-langkah berikut untuk mengadaptasi kode ini dengan data sensor Anda sendiri:
#
# ---
#
# #### **TODO 1: Konfigurasi Sensor Anda** ⚙️
# **File/Cell: Section 2 - Konfigurasi Kafka**
#
# - [ ] **Ganti nama topic** sesuai dengan use case Anda
#   - Contoh: `'temperature-monitor'`, `'air-quality'`, `'machine-vibration'`
#
# - [ ] **Definisikan sensor IDs** Anda sendiri
#   - Contoh: `['TEMP_01', 'TEMP_02']`, `['AQ_SENSOR_A', 'AQ_SENSOR_B']`
#
# - [ ] **Tentukan lokasi sensor** yang relevan
#   - Contoh: `['Lantai 1', 'Lantai 2']`, `['Indoor', 'Outdoor']`
#
# ```python
# # Contoh modifikasi:
# TOPIC_NAME = 'suhu-ruangan-kampus'
# SENSOR_IDS = ['TEMP_A01', 'TEMP_A02', 'TEMP_B01']
# SENSOR_LOCATIONS = ['Ruang Kelas A', 'Lab Komputer', 'Perpustakaan']
# ```
#
# ---
#
# #### **TODO 2: Modifikasi Data Sensor** 📊
# **File/Cell: Section 3 - Fungsi Helper untuk Generate Data Sensor**
#
# - [ ] **Sesuaikan parameter sensor** dengan jenis data Anda:
#   - Ubah range nilai (min-max)
#   - Tambah atau kurangi parameter
#   - Sesuaikan satuan pengukuran
#
# - [ ] **Contoh modifikasi untuk sensor CO2:**
# ```python
# sensor_reading = {
#     'sensor_id': sensor_id,
#     'location': location,
#     'timestamp': datetime.now().isoformat(),
#     'co2_ppm': round(random.uniform(400, 1000), 2),  # CO2 dalam ppm
#     'temperature': round(base_temp + random.uniform(-2, 2), 2),
#     'noise_level': round(random.uniform(30, 80), 2),  # dB
#     'status': 'normal' if co2_ppm < 800 else 'warning'
# }
# ```
#
# - [ ] **Contoh untuk sensor getaran mesin:**
# ```python
# sensor_reading = {
#     'sensor_id': sensor_id,
#     'machine_name': machine_name,
#     'timestamp': datetime.now().isoformat(),
#     'vibration_x': round(random.uniform(0, 5), 3),  # mm/s
#     'vibration_y': round(random.uniform(0, 5), 3),
#     'vibration_z': round(random.uniform(0, 5), 3),
#     'rpm': round(random.uniform(1000, 3000), 0),
#     'status': 'normal'
# }
# ```
#
# ---
#
# #### **TODO 3: Ubah Threshold Alert** 🚨
# **File/Cell: Section 10 - Stream Processing dengan Windowing**
#
# - [ ] **Sesuaikan kondisi alert** berdasarkan use case Anda
# - [ ] **Tentukan threshold yang tepat** untuk data Anda
#
# ```python
# # Contoh modifikasi di method process_message():
# alerts = []
#
# # Untuk monitoring kualitas udara:
# if avg_co2 > 800:
#     alerts.append(f"⚠️ CO2 tinggi: {avg_co2:.0f} ppm")
# if avg_temp > 28:
#     alerts.append(f"🔥 Suhu tidak nyaman: {avg_temp:.1f}°C")
# if avg_noise > 70:
#     alerts.append(f"🔊 Kebisingan tinggi: {avg_noise:.0f} dB")
#
# # Untuk monitoring mesin:
# if avg_vibration > 3.5:
#     alerts.append(f"⚡ Getaran abnormal: {avg_vibration:.2f} mm/s")
# if avg_rpm < 1500 or avg_rpm > 2500:
#     alerts.append(f"⚙️ RPM di luar range: {avg_rpm:.0f}")
# ```
#
# ---
#
# #### **TODO 4: Sesuaikan Visualisasi** 📈
# **File/Cell: Section 9 - Visualisasi Data Sensor**
#
# - [ ] **Ubah judul grafik** sesuai dengan parameter Anda
# - [ ] **Ganti label axis** dengan satuan yang sesuai
# - [ ] **Tambah atau kurangi subplot** sesuai jumlah parameter
#
# ```python
# # Contoh untuk 2 parameter (CO2 dan Suhu):
# fig, axes = plt.subplots(2, 1, figsize=(14, 8))
#
# # Plot 1: CO2
# axes[0].set_title('🌫️ CO2 Levels Over Time')
# axes[0].set_ylabel('CO2 (ppm)')
# axes[0].axhline(y=800, color='r', linestyle='--', label='Safe Limit')
#
# # Plot 2: Temperature
# axes[1].set_title('🌡️ Temperature Over Time')
# axes[1].set_ylabel('Temperature (°C)')
# axes[1].axhline(y=28, color='r', linestyle='--', label='Comfort Limit')
# ```
#
# ---
#
# #### **TODO 5: Ubah Ukuran Window** 🪟
# **File/Cell: Section 10 & 11**
#
# - [ ] **Tentukan window_size** yang tepat untuk analisis Anda:
#   - Window kecil (3-5): Untuk deteksi cepat perubahan mendadak
#   - Window sedang (10-20): Untuk smoothing noise
#   - Window besar (50+): Untuk trend jangka panjang
#
# ```python
# # Contoh:
# processor = StreamProcessor(window_size=10)  # Ubah sesuai kebutuhan
# ```
#
# ---
#
# #### **TODO 6: Konfigurasi Kafka Connection** 🔌
# **File/Cell: Section 2**
#
# - [ ] **Sesuaikan Kafka server address** jika menggunakan server lain
# - [ ] **Tambahkan konfigurasi keamanan** jika diperlukan
#
# ```python
# # Jika Kafka di server lain:
# KAFKA_BOOTSTRAP_SERVERS = ['192.168.1.100:9092']
#
# # Jika menggunakan authentication:
# producer = KafkaProducer(
#     bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
#     security_protocol='SASL_SSL',
#     sasl_mechanism='PLAIN',
#     sasl_plain_username='your_username',
#     sasl_plain_password='your_password',
#     value_serializer=lambda v: json.dumps(v).encode('utf-8')
# )
# ```
#
# ---
#
# #### **TODO 7: Tambahkan Data Real dari Hardware** 🔧(jika anda punya, jika tidak buat dummy data)
# **File/Cell: Buat cell baru**
#
# - [ ] **Integrasikan dengan sensor fisik** (Arduino, Raspberry Pi, ESP32)
# - [ ] **Ganti fungsi generate_sensor_data()** dengan pembacaan sensor real
#
# ```python
# # Contoh integrasi dengan Raspberry Pi dan DHT22:
# import Adafruit_DHT
#
# def read_real_sensor_data(sensor_id, gpio_pin):
#     """Baca data dari sensor DHT22"""
#     sensor = Adafruit_DHT.DHT22
#     humidity, temperature = Adafruit_DHT.read_retry(sensor, gpio_pin)
#
#     if humidity is not None and temperature is not None:
#         return {
#             'sensor_id': sensor_id,
#             'location': 'Lab IoT',
#             'timestamp': datetime.now().isoformat(),
#             'temperature': round(temperature, 2),
#             'humidity': round(humidity, 2),
#             'status': 'normal' if temperature < 30 else 'warning'
#         }
#     else:
#         return None
#
# # Gunakan di producer:
# # data = read_real_sensor_data('SENSOR_001', gpio_pin=4)
# ```
#
# ---
#
# #### **TODO 8: Simpan ke Database** 💾
# **File/Cell: Buat cell baru**
#
# - [ ] **Tambahkan koneksi ke database** untuk menyimpan data historis
# - [ ] **Pilih database** yang sesuai: PostgreSQL, MongoDB, InfluxDB, TimescaleDB
#
# ```python
# # Contoh dengan PostgreSQL:
# import psycopg2
# from psycopg2.extras import Json
#
# def save_to_database(data):
#     conn = psycopg2.connect(
#         host="localhost",
#         database="sensor_db",
#         user="your_user",
#         password="your_password"
#     )
#     cur = conn.cursor()
#
#     cur.execute("""
#         INSERT INTO sensor_readings
#         (sensor_id, location, timestamp, temperature, humidity, status)
#         VALUES (%s, %s, %s, %s, %s, %s)
#     """, (
#         data['sensor_id'],
#         data['location'],
#         data['timestamp'],
#         data['temperature'],
#         data['humidity'],
#         data['status']
#     ))
#
#     conn.commit()
#     cur.close()
#     conn.close()
#
# # Panggil di consumer setelah menerima message:
# # save_to_database(message.value)
# ```
#
# ---
#
# #### **TODO 9: Buat Dashboard Real-time** 📊
# **File/Cell: Buat cell baru**
#
# - [ ] **Gunakan Plotly/Dash** untuk dashboard interaktif
# - [ ] **Atau gunakan Streamlit** untuk web app sederhana
#
# ```python
# # Contoh dengan Plotly untuk live update:
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go
# from IPython.display import clear_output
#
# def create_live_dashboard(data_buffer, update_interval=2):
#     \"\"\"Dashboard yang update secara real-time\"\"\"
#     fig = make_subplots(
#         rows=2, cols=1,
#         subplot_titles=('Temperature', 'Humidity')
#     )
#
#     # Update loop
#     while True:
#         df = pd.DataFrame(data_buffer)
#         if not df.empty:
#             df['timestamp'] = pd.to_datetime(df['timestamp'])
#
#             fig.add_trace(
#                 go.Scatter(x=df['timestamp'], y=df['temperature'], mode='lines'),
#                 row=1, col=1
#             )
#
#             clear_output(wait=True)
#             fig.show()
#
#         time.sleep(update_interval)
# ```
#
# ---
#
# #### **TODO 10: Testing dan Validasi** ✅
# **File/Cell: Buat cell baru**
#
# - [ ] **Buat unit tests** untuk fungsi-fungsi penting
# - [ ] **Validasi data** sebelum dikirim ke Kafka
# - [ ] **Test error handling**
#
# ```python
# # Contoh validasi data:
# def validate_sensor_data(data):
#     \"\"\"Validasi data sensor sebelum dikirim\"\"\"
#     required_fields = ['sensor_id', 'timestamp', 'temperature']
#
#     # Check required fields
#     for field in required_fields:
#         if field not in data:
#             raise ValueError(f"Missing required field: {field}")
#
#     # Validate temperature range
#     if not -50 <= data['temperature'] <= 100:
#         raise ValueError(f"Temperature out of range: {data['temperature']}")
#
#     # Validate timestamp format
#     try:
#         datetime.fromisoformat(data['timestamp'])
#     except ValueError:
#         raise ValueError("Invalid timestamp format")
#
#     return True
#
# # Gunakan sebelum send:
# # if validate_sensor_data(data):
# #     producer.send(topic, data)
# ```
#
# ---
#
# ### 🎓 **Tips untuk Mahasiswa:**
#
# 1. **Mulai dari yang sederhana**: Modifikasi satu parameter dulu, test, baru lanjut
# 2. **Dokumentasi**: Catat setiap perubahan yang Anda buat
# 3. **Version control**: Gunakan Git untuk track perubahan
# 4. **Testing**: Selalu test setelah setiap modifikasi
# 5. **Kolaborasi**: Diskusikan dengan teman atau dosen jika ada kesulitan
#
# ---
#
# ### 📚 **Referensi Tambahan:**
#
# - **Kafka Documentation**: https://kafka.apache.org/documentation/
# - **IoT Sensor Integration**:
#   - Arduino + Kafka: https://github.com/edenhill/librdkafka
#   - Raspberry Pi + Kafka: https://www.confluent.io/blog/raspberry-pi-kafka/
# - **Data Visualization**:
#   - Plotly: https://plotly.com/python/
#   - Streamlit: https://streamlit.io/
# - **Time Series Database**:
#   - InfluxDB: https://www.influxdata.com/
#   - TimescaleDB: https://www.timescale.com/
#
# ---
#
# ### ✨ **Ide Project Lanjutan:**
#
# 1. **Predictive Maintenance**: Gunakan ML untuk prediksi kerusakan mesin
# 2. **Multi-location Monitoring**: Dashboard untuk monitoring banyak lokasi
# 3. **Alert Notification**: Kirim notifikasi via Email/Telegram/WhatsApp
# 4. **Data Analytics**: Analisis pola dan trend jangka panjang
# 5. **Mobile App**: Buat app mobile untuk monitoring
# 6. **Edge Computing**: Processing di edge device sebelum kirim ke Kafka
# 7. **Anomaly Detection**: Implementasi ML untuk deteksi anomali otomatis
#
# ---
#
# **Good luck! 🚀 Selamat bereksperimen dengan data sensor Anda!**
